# %%
import os
os.environ['OPENAI_API_KEY']
# Out:
# 'sk-6e1e4e791ae94585bbabb61be596c568'

# %% [markdown]
# # 角色扮演
#
# 结论：简单的角色扮演效果不太明显

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate


prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an AI assisant that helps people find information."),
        ("human", "{input}"),
    ]
)

llm = ChatOpenAI(base_url="https://dashscope.aliyuncs.com/compatible-mode/v1", model="qwen-max")

chain = prompt | llm

chain.invoke(
    {"input": "给我一个减肥计划"}
).pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 减肥计划需要综合考虑饮食、运动和生活习惯等多个方面，同时建议在开始任何减肥计划前咨询医生或营养师，确保计划适合您的健康状况。以下是一个基本的减肥计划示例，供参考：
#
# ### 1. 饮食调整
#
# - **均衡膳食**：确保摄入足够的蛋白质（如鸡胸肉、鱼、豆类）、复合碳水化合物（如糙米、燕麦、全麦面包）、蔬菜和水果。减少加工食品和高糖食品的摄入。
# - **控制热量**：根据您的年龄、性别、体重和活动量计算每日所需热量，并适当减少约500卡路里以达到每周减轻约0.5-1公斤的目标。
# - **多餐少食**：保持一天三餐加一到两次健康零食，避免饥饿感导致暴饮暴食。
# - **水分充足**：每天至少喝8杯水，有助于提升新陈代谢和减少饥饿感。
#
# ### 2. 运动计划
#
# - **有氧运动**：每周至少150分钟的中等强度有氧运动，如快走、慢跑、游泳或骑自行车。可以分为每天30分钟，5天进行。
# - **力量训练**：每周至少进行两天的力量训练，可以帮助增加肌肉量，提高基础代谢率。可以包括哑铃锻炼、俯卧撑、深蹲等。
# - **灵活性和平衡性训练**：瑜伽或太极等，帮助放松身心，提高身体柔韧性和平衡能力。
#
# ### 3. 生活习惯
#
# - **充足睡眠**：保证每晚7-9小时的高质量睡眠，有助于调节激素水平，减少饥饿感。
# - **减压**：通过冥想、深呼吸、阅读等方式缓解压力，避免情绪化进食。
# - **记录饮食与运动**：使用APP记录每日的饮食摄入和运动情况，帮助自我监控和调整。
# - **设定实际目标**：设立短期和长期的可达成目标，比如每周减重0.5公斤，而不是期望迅速减肥。
#
# 请记住，持之以恒是关键，健康的减肥速度应该是逐步且稳定的。如果在执行过程中遇到困难或疑问，及时寻求专业人士的帮助。

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "我想让你扮演一个专业的健身私人教练，你应该利用你的运动科学知识、营养建议和其他相关因素为你的客户定制专业的计划。"),
        ("human", "{input}"),
    ]
)

chain = prompt | llm

result = chain.invoke(
    {"input": "给我一个减肥计划"}
).pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 当然，很高兴为您提供一个个性化的减肥计划。请注意，任何减肥计划都应考虑个人的健康状况、体重、身高、年龄、性别及生活方式等因素。以下是一个基本框架，但强烈建议在开始前咨询医生或专业营养师。
#
# ### 目标设定
# - 确定实际可行的短期与长期目标（例如，一个月内减重2公斤，半年内达到理想体重）。
# - 专注于身体成分改变而非仅关注体重数字，如减少体脂比例，增加肌肉量。
#
# ### 饮食计划
# 1. **平衡摄入**：确保每日摄入均衡的蛋白质（鸡肉、鱼、豆腐等）、复合碳水化合物（糙米、燕麦、蔬菜等）和健康脂肪（坚果、鳄梨、橄榄油）。
# 2. **控制热量**：根据您的基础代谢率(BMR)和日常活动量计算所需的热量摄入，一般建议比维持体重所需的热量低500卡路里/天，以实现每周减重约0.5-1公斤。
# 3. **水分充足**：每天至少喝8杯水，有助于新陈代谢和减少饥饿感。
# 4. **避免加工食品**：减少糖分、精制面粉制品和高盐食物的摄入。
# 5. **定时进食**：保持规律的饮食习惯，避免长时间不吃导致过度饥饿而暴饮暴食。
#
# ### 运动计划
# 1. **有氧运动**：每周至少150分钟中等强度或75分钟高强度的有氧运动（快走、慢跑、游泳、骑自行车等），分成多个时段进行。
# 2. **力量训练**：每周至少两天进行全身或分部位的力量训练，帮助增加肌肉量，提高基础代谢率。
# 3. **灵活性和平衡**：加入瑜伽或普拉提，提升身体柔韧性和核心稳定性。
# 4. **HIIT训练**：高强度间歇训练可在短时间内燃烧大量卡路里，每周一到两次，根据身体适应情况调整。
#
# ### 生活方式调整
# 1. **充足睡眠**：每晚7-9小时高质量睡眠，有助于调节激素水平，减少食欲。
# 2. **压力管理**：通过冥想、深呼吸、轻松阅读等方式减轻压力，避免情绪化进食。
# 3. **持续监测**：记录饮食、运动和体重变化，定期评估进度并调整计划。
#
# 请记住，减肥是一个渐进的过程，需要耐心和坚持。同时，倾听身体的信号，避免过度训练和极端节食，保证健康安全。祝您成功！
